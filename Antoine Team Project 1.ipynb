# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import datetime as dt
import numpy as np
from scipy.stats import linregress


# Study data files
cobra_09_path = "data/COBRA-2009-2019.csv"
cobra_20_path = "data/COBRA-2020.csv"
cobra_20_Old_path = "data/COBRA-2020-Old.csv"
cobra_21_path = "data/COBRA-2021.csv"
county_cases_path = "data/county_cases.csv"

# Read the mouse data and the study results
cobra_09 = pd.read_csv(cobra_09_path, low_memory=False)
cobra_20 = pd.read_csv(cobra_20_path)
cobra_20_Old = pd.read_csv(cobra_20_Old_path)
cobra_21 = pd.read_csv(cobra_21_path)
county_cases = pd.read_csv(county_cases_path)


# Combine the data into a single dataset
#study_data_complete = pd.merge(study_results, mouse_metadata, how="left", on="Mouse ID")

# Display the data table for preview
#study_data_complete

# %%
cobra_09.columns = ['offense_id','rpt_date','occur_date','occur_time','poss_date','poss_time','beat','apt_office_prefix', 'apt_office_num', 'location', 'shift_occurence','location_type','UC2_Literal','UC2#','ibr_code','neighborhood','npu','lat','long']
cobra_09 = cobra_09.drop(columns = ['apt_office_prefix','apt_office_num','shift_occurence','location_type','UC2#', 'poss_date'])

# %%
cobra_09['rpt_date']= pd.to_datetime(cobra_09['rpt_date'])
cobra_09['occur_date']= pd.to_datetime(cobra_09['occur_date'])
cobra_09['rpt_date'] = cobra_09['rpt_date'].dt.strftime("%m/%d/%Y")
cobra_09['occur_date'] = cobra_09['occur_date'].dt.strftime("%m/%d/%Y")
cobra_09.head()
# Out:
#    offense_id    rpt_date  occur_date occur_time  poss_time   beat  \
# 0    90010930  01/01/2009  01/01/2009       1145     1148.0  411.0
# 1    90011083  01/01/2009  01/01/2009       1330     1330.0  511.0
# 2    90011208  01/01/2009  01/01/2009       1500     1520.0  407.0
# 3    90011218  01/01/2009  01/01/2009       1450     1510.0  210.0
# 4    90011289  01/01/2009  01/01/2009       1600     1700.0  411.0
#
#                       location          UC2_Literal ibr_code neighborhood npu  \
# 0         2841 GREENBRIAR PKWY  LARCENY-NON VEHICLE     2303   Greenbriar   R
# 1               12 BROAD ST SW  LARCENY-NON VEHICLE     2303     Downtown   M
# 2  3500 MARTIN L KING JR DR SW  LARCENY-NON VEHICLE     2303   Adamsville   H
# 3         3393 PEACHTREE RD NE  LARCENY-NON VEHICLE     2303        Lenox   B
# 4      2841 GREENBRIAR PKWY SW  LARCENY-NON VEHICLE     2303   Greenbriar   R
#
#         lat      long
# 0  33.68845 -84.49328
# 1  33.75320 -84.39201
# 2  33.75735 -84.50282
# 3  33.84676 -84.36212
# 4  33.68677 -84.49773

# %%
cobra_09.insert(3,'occur_year',cobra_09['occur_date'].str[-4:])
cobra_09_delete = cobra_09.loc[cobra_09['occur_year'].str[:2] != '20']
cobra_09_delete_list = cobra_09_delete['offense_id'].to_list()
cobra_09 = cobra_09[~cobra_09['offense_id'].isin(cobra_09_delete_list)]
cobra_09
# Out:
#         offense_id    rpt_date  occur_date occur_year occur_time  poss_time  \
# 0         90010930  01/01/2009  01/01/2009       2009       1145     1148.0
# 1         90011083  01/01/2009  01/01/2009       2009       1330     1330.0
# 2         90011208  01/01/2009  01/01/2009       2009       1500     1520.0
# 3         90011218  01/01/2009  01/01/2009       2009       1450     1510.0
# 4         90011289  01/01/2009  01/01/2009       2009       1600     1700.0
# ...            ...         ...         ...        ...        ...        ...
# 342909   193652089  12/31/2019  12/31/2019       2019       2030     2034.0
# 342910   193650336  12/31/2019  12/31/2019       2019       0432      432.0
# 342911   193650603  12/31/2019  12/31/2019       2019       0920      940.0
# 342912   193651760  12/31/2019  12/31/2019       2019       1853     1900.0
# 342913   193652591  12/31/2019  12/31/2019       2019       2045     2055.0
#
#          beat                     location          UC2_Literal ibr_code  \
# 0       411.0         2841 GREENBRIAR PKWY  LARCENY-NON VEHICLE     2303
# 1       511.0               12 BROAD ST SW  LARCENY-NON VEHICLE     2303
# 2       407.0  3500 MARTIN L KING JR DR SW  LARCENY-NON VEHICLE     2303
# 3       210.0         3393 PEACHTREE RD NE  LARCENY-NON VEHICLE     2303
# 4       411.0      2841 GREENBRIAR PKWY SW  LARCENY-NON VEHICLE     2303
# ...       ...                          ...                  ...      ...
# 342909  105.0            1385 SHARON ST NW          AGG ASSAULT    1315K
# 342910  206.0              262 PHARR RD NE          AGG ASSAULT     1314
# 342911  404.0           689 CASCADE AVE SW          AGG ASSAULT     1314
# 342912  404.0           763 CASCADE AVE SW          AGG ASSAULT     1314
# 342913  406.0             237 PEYTON PL SW          AGG ASSAULT     1314
#
#                neighborhood npu       lat      long
# 0                Greenbriar   R  33.68845 -84.49328
# 1                  Downtown   M  33.75320 -84.39201
# 2                Adamsville   H  33.75735 -84.50282
# 3                     Lenox   B  33.84676 -84.36212
# 4                Greenbriar   R  33.68677 -84.49773
# ...                     ...  ..       ...       ...
# 342909         Hunter Hills   K  33.75486 -84.43287
# 342910     Buckhead Village   B  33.83732 -84.37860
# 342911             Westview   T  33.73636 -84.43680
# 342912             Westview   T  33.73483 -84.43750
# 342913  Cascade Avenue/Road   S  33.72518 -84.45013
#
# [342894 rows x 14 columns]

# %%
cobra_20_Old.columns = ['offense_id','rpt_date','occur_date','occur_time','poss_date','poss_time','beat','apt_office_prefix', 'apt_office_num', 'location', 'shift_occurence','location_type','UC2_Literal','UC2#','neighborhood','npu','lat','long']
cobra_20_Old = cobra_20_Old.drop(columns = ['apt_office_prefix','apt_office_num','shift_occurence','location_type','UC2#', 'poss_date'])
cobra_20_Old
# Out:
#        offense_id rpt_date occur_date occur_time poss_time   beat  \
# 0       200021209   1/2/20     1/2/20      15:21     15:35  511.0
# 1       200061707   1/6/20     1/6/20       0:00     18:25  109.0
# 2       200100013  1/10/20     1/9/20      23:45      0:00  110.0
# 3       200151818  1/16/20    1/15/20      17:15     17:40  401.0
# 4       200180440  1/18/20    1/18/20       3:31      3:31  206.0
# ...           ...      ...        ...        ...       ...    ...
# 14826   202670466  9/23/20    9/22/20      18:00      9:00  609.0
# 14827   202670717  9/23/20    9/22/20      21:30     10:00  609.0
# 14828   202680455  9/24/20    9/23/20      23:00      7:00  609.0
# 14829   202731007  9/29/20    9/26/20      18:00     14:30  607.0
# 14830   202731640  9/29/20    9/29/20      20:30     21:00  504.0
#
#                      location UC2_Literal            neighborhood npu  \
# 0              12 BROAD ST SW    HOMICIDE                Downtown   M
# 1           785 PEYTON AVE NW    HOMICIDE             Center Hill   J
# 2           1977 JONES AVE NW    HOMICIDE          West Highlands   G
# 3      549 JOSEPH LOWERY BLVD    HOMICIDE                West End   T
# 4              28 IRBY AVE NW    HOMICIDE       South Tuxedo Park   B
# ...                       ...         ...                     ...  ..
# 14826       1207 HARDEE ST NE  AUTO THEFT                Edgewood   O
# 14827      195 ARIZONA AVE NE  AUTO THEFT                Edgewood   O
# 14828    1661 LA FRANCE ST NE  AUTO THEFT                Edgewood   O
# 14829     694 SCHUYLER AVE SE  AUTO THEFT       Boulevard Heights   W
# 14830      768 MARIETTA ST NW  AUTO THEFT  Marietta Street Artery   E
#
#             lat      long
# 0      33.75352 -84.39189
# 1      33.77655 -84.46770
# 2      33.78738 -84.45208
# 3      33.74001 -84.41782
# 4      33.84102 -84.38018
# ...         ...       ...
# 14826  33.75524 -84.34801
# 14827  33.75929 -84.33120
# 14828  33.76103 -84.33185
# 14829  33.72520 -84.36533
# 14830  33.77331 -84.40403
#
# [14831 rows x 12 columns]

# %%
cobra_20_Old['rpt_date']= pd.to_datetime(cobra_20_Old['rpt_date'])
cobra_20_Old['occur_date']= pd.to_datetime(cobra_20_Old['occur_date'])
cobra_20_Old['rpt_date'] = cobra_20_Old['rpt_date'].dt.strftime("%m/%d/%Y")
cobra_20_Old['occur_date'] = cobra_20_Old['occur_date'].dt.strftime("%m/%d/%Y")
cobra_20_Old.head()
# Out:
#    offense_id    rpt_date  occur_date occur_time poss_time   beat  \
# 0   200021209  01/02/2020  01/02/2020      15:21     15:35  511.0
# 1   200061707  01/06/2020  01/06/2020       0:00     18:25  109.0
# 2   200100013  01/10/2020  01/09/2020      23:45      0:00  110.0
# 3   200151818  01/16/2020  01/15/2020      17:15     17:40  401.0
# 4   200180440  01/18/2020  01/18/2020       3:31      3:31  206.0
#
#                  location UC2_Literal       neighborhood npu       lat  \
# 0          12 BROAD ST SW    HOMICIDE           Downtown   M  33.75352
# 1       785 PEYTON AVE NW    HOMICIDE        Center Hill   J  33.77655
# 2       1977 JONES AVE NW    HOMICIDE     West Highlands   G  33.78738
# 3  549 JOSEPH LOWERY BLVD    HOMICIDE           West End   T  33.74001
# 4          28 IRBY AVE NW    HOMICIDE  South Tuxedo Park   B  33.84102
#
#        long
# 0 -84.39189
# 1 -84.46770
# 2 -84.45208
# 3 -84.41782
# 4 -84.38018

# %%
cobra_20_Old.insert(3,'occur_year',cobra_20_Old['occur_date'].str[-4:])
cobra_20_Old_delete = cobra_20_Old.loc[cobra_20_Old['occur_year'].str[:2] != '20']
cobra_20_Old_delete_list = cobra_20_Old_delete['offense_id'].to_list()
cobra_20_Old = cobra_20_Old[~cobra_20_Old['offense_id'].isin(cobra_20_Old_delete_list)]
cobra_20_Old
# Out:
#        offense_id    rpt_date  occur_date occur_year occur_time poss_time  \
# 0       200021209  01/02/2020  01/02/2020       2020      15:21     15:35
# 1       200061707  01/06/2020  01/06/2020       2020       0:00     18:25
# 2       200100013  01/10/2020  01/09/2020       2020      23:45      0:00
# 3       200151818  01/16/2020  01/15/2020       2020      17:15     17:40
# 4       200180440  01/18/2020  01/18/2020       2020       3:31      3:31
# ...           ...         ...         ...        ...        ...       ...
# 14826   202670466  09/23/2020  09/22/2020       2020      18:00      9:00
# 14827   202670717  09/23/2020  09/22/2020       2020      21:30     10:00
# 14828   202680455  09/24/2020  09/23/2020       2020      23:00      7:00
# 14829   202731007  09/29/2020  09/26/2020       2020      18:00     14:30
# 14830   202731640  09/29/2020  09/29/2020       2020      20:30     21:00
#
#         beat                location UC2_Literal            neighborhood npu  \
# 0      511.0          12 BROAD ST SW    HOMICIDE                Downtown   M
# 1      109.0       785 PEYTON AVE NW    HOMICIDE             Center Hill   J
# 2      110.0       1977 JONES AVE NW    HOMICIDE          West Highlands   G
# 3      401.0  549 JOSEPH LOWERY BLVD    HOMICIDE                West End   T
# 4      206.0          28 IRBY AVE NW    HOMICIDE       South Tuxedo Park   B
# ...      ...                     ...         ...                     ...  ..
# 14826  609.0       1207 HARDEE ST NE  AUTO THEFT                Edgewood   O
# 14827  609.0      195 ARIZONA AVE NE  AUTO THEFT                Edgewood   O
# 14828  609.0    1661 LA FRANCE ST NE  AUTO THEFT                Edgewood   O
# 14829  607.0     694 SCHUYLER AVE SE  AUTO THEFT       Boulevard Heights   W
# 14830  504.0      768 MARIETTA ST NW  AUTO THEFT  Marietta Street Artery   E
#
#             lat      long
# 0      33.75352 -84.39189
# 1      33.77655 -84.46770
# 2      33.78738 -84.45208
# 3      33.74001 -84.41782
# 4      33.84102 -84.38018
# ...         ...       ...
# 14826  33.75524 -84.34801
# 14827  33.75929 -84.33120
# 14828  33.76103 -84.33185
# 14829  33.72520 -84.36533
# 14830  33.77331 -84.40403
#
# [14830 rows x 13 columns]

# %%
cobra_20 = cobra_20.drop(columns = ['apt_office_prefix','apt_office_num','MinOfucr','dispo_code','Shift','loc_type', 'poss_date'])
cobra_20_reorder = ['offense_id','rpt_date','occur_date','occur_time','poss_time','beat','location','ibr_code','UC2_Literal','neighborhood','npu','lat','long']
cobra_20_reordered = cobra_20.reindex(columns = cobra_20_reorder)
cobra_20 = cobra_20_reordered.copy()

# %%
cobra_20.insert(3,'occur_year',cobra_20['occur_date'].str[-4:])
cobra_20_delete = cobra_20.loc[cobra_20['occur_year'].str[:2] != '20']
cobra_20_delete_list = cobra_20_delete['offense_id'].to_list()
cobra_20 = cobra_20[~cobra_20['offense_id'].isin(cobra_20_delete_list)]
cobra_20.head()
# Out:
#    offense_id    rpt_date  occur_date occur_year occur_time poss_time beat  \
# 0   203341346  12/31/2020  11/29/2020       2020      19:21     23:50  405
# 1   203631200  12/31/2020  12/28/2020       2020      17:21     17:45  302
# 2   203631285  12/31/2020  12/24/2020       2020      14:00     18:26  603
# 3   203651634  12/31/2020  12/30/2020       2020      20:15     22:25  211
# 4   203660108  12/31/2020  12/31/2020       2020       1:15      1:15  306
#
#                location ibr_code           UC2_Literal     neighborhood npu  \
# 0  3050 M.L.K. JR DR SW      13A           AGG ASSAULT  Harland Terrace   I
# 1        1186 IRA ST SW      23H   LARCENY-NON VEHICLE       Pittsburgh   V
# 2   501 BOULEVARD PL NE      23H   LARCENY-NON VEHICLE  Old Fourth Ward   M
# 3   3101 PIEDMONT RD NE      23F  LARCENY-FROM VEHICLE   Peachtree Park   B
# 4     1974 SYLVAN RD SW      13A           AGG ASSAULT     Sylvan Hills   X
#
#          lat       long
# 0  33.751060 -84.486163
# 1  33.722696 -84.399763
# 2  33.769680 -84.370736
# 3  33.840653 -84.369361
# 4  33.700432 -84.418128

# %%
cobra_20['rpt_date']= pd.to_datetime(cobra_20['rpt_date'])
cobra_20['occur_date']= pd.to_datetime(cobra_20['occur_date'])
cobra_20['rpt_date'] = cobra_20['rpt_date'].dt.strftime("%m/%d/%Y")
cobra_20['occur_date'] = cobra_20['occur_date'].dt.strftime("%m/%d/%Y")
cobra_20.head()
# Out:
#    offense_id    rpt_date  occur_date occur_year occur_time poss_time beat  \
# 0   203341346  12/31/2020  11/29/2020       2020      19:21     23:50  405
# 1   203631200  12/31/2020  12/28/2020       2020      17:21     17:45  302
# 2   203631285  12/31/2020  12/24/2020       2020      14:00     18:26  603
# 3   203651634  12/31/2020  12/30/2020       2020      20:15     22:25  211
# 4   203660108  12/31/2020  12/31/2020       2020       1:15      1:15  306
#
#                location ibr_code           UC2_Literal     neighborhood npu  \
# 0  3050 M.L.K. JR DR SW      13A           AGG ASSAULT  Harland Terrace   I
# 1        1186 IRA ST SW      23H   LARCENY-NON VEHICLE       Pittsburgh   V
# 2   501 BOULEVARD PL NE      23H   LARCENY-NON VEHICLE  Old Fourth Ward   M
# 3   3101 PIEDMONT RD NE      23F  LARCENY-FROM VEHICLE   Peachtree Park   B
# 4     1974 SYLVAN RD SW      13A           AGG ASSAULT     Sylvan Hills   X
#
#          lat       long
# 0  33.751060 -84.486163
# 1  33.722696 -84.399763
# 2  33.769680 -84.370736
# 3  33.840653 -84.369361
# 4  33.700432 -84.418128

# %%
cobra_21 = cobra_21.drop(columns = ['occur_day','occur_day_num','occur_day_num','zone', 'poss_date'])
cobra_21.head()
# Out:
#    offense_id   rpt_date occur_date occur_time poss_time  beat  \
# 0    21140096  5/20/2021  5/19/2021      15:20     15:25   103
# 1    21282015   8/6/2021   8/6/2021      22:23     22:24   508
# 2    21791668  6/28/2021  6/27/2021      21:17     20:00   102
# 3   200041082   1/5/2021   1/4/2021      16:00     17:00   605
# 4   202611428  9/18/2021  9/18/2021      18:04     18:15   112
#
#                                             location ibr_code  \
# 0  1720 MARIETTA BLVD NW\r\nATLANTA, GA 30318\r\n...      23F
# 1  300 PEACHTREE ST NE\r\nATLANTA, GA 30308\r\nUN...      23F
# 2  870 MAYSON TURNER RD NW\r\nATLANTA, GA 30314\r...      23H
# 3  275 MEMORIAL DR SE\r\nATLANTA, GEORGIA 30312\r...      23C
# 4  2750 DONALD LEE HOLLOWELL PKWY NW\r\nATLANTA, ...      23C
#
#             UC2_Literal     neighborhood npu        lat       long
# 0  LARCENY-FROM VEHICLE       Hills Park   D  33.801693 -84.436453
# 1  LARCENY-FROM VEHICLE         Downtown   M  33.762549 -84.387874
# 2   LARCENY-NON VEHICLE        Vine City   L  33.755768 -84.416631
# 3   LARCENY-NON VEHICLE       Grant Park   W  33.746503 -84.378535
# 4   LARCENY-NON VEHICLE  Collier Heights   I  33.777383 -84.477433

# %%
cobra_21.insert(3,'occur_year',cobra_21['occur_date'].str[-4:])
cobra_21_delete = cobra_21.loc[cobra_21['occur_year'].str[:2] != '20']
cobra_21_delete_list = cobra_21_delete['offense_id'].to_list()
cobra_21 = cobra_21[~cobra_21['offense_id'].isin(cobra_21_delete_list)]
cobra_21
# Out:
#        offense_id    rpt_date  occur_date occur_year occur_time poss_time  \
# 0        21140096   5/20/2021   5/19/2021       2021      15:20     15:25
# 1        21282015    8/6/2021    8/6/2021       2021      22:23     22:24
# 2        21791668   6/28/2021   6/27/2021       2021      21:17     20:00
# 3       200041082    1/5/2021    1/4/2021       2021      16:00     17:00
# 4       202611428   9/18/2021   9/18/2021       2021      18:04     18:15
# ...           ...         ...         ...        ...        ...       ...
# 17627   212940064  10/21/2021  10/21/2021       2021      02:24     02:25
# 17628   212940073  10/21/2021  10/21/2021       2021      00:35     00:45
# 17629   212940212  10/21/2021  10/21/2021       2021      02:49     03:28
# 17630   213000875   8/18/2021   7/10/2021       2021      16:00     12:14
# 17631   217421582   10/1/2021   10/1/2021       2021      00:00     20:00
#
#        beat                                           location ibr_code  \
# 0       103  1720 MARIETTA BLVD NW\r\nATLANTA, GA 30318\r\n...      23F
# 1       508  300 PEACHTREE ST NE\r\nATLANTA, GA 30308\r\nUN...      23F
# 2       102  870 MAYSON TURNER RD NW\r\nATLANTA, GA 30314\r...      23H
# 3       605  275 MEMORIAL DR SE\r\nATLANTA, GEORGIA 30312\r...      23C
# 4       112  2750 DONALD LEE HOLLOWELL PKWY NW\r\nATLANTA, ...      23C
# ...     ...                                                ...      ...
# 17627   112  3200 DONALD LEE HOLLOWELL PKWY NW\r\nATLANTA, ...      23F
# 17628   111  71 LINKWOOD RD NW\r\nATL, GA 30311\r\nUNITED S...      13A
# 17629   409  3113 CAMPBELLTON RD SW\r\nATLANTA, GA 30311\r\...      240
# 17630   612  491 FLAT SHOALS AVE SE\r\nATLANTA, GA 30316\r\...      23F
# 17631   605  655 MEAD ST SE\r\nATLANTA, GA 30312\r\nUNITED ...      23G
#
#                 UC2_Literal     neighborhood npu        lat       long
# 0      LARCENY-FROM VEHICLE       Hills Park   D  33.801693 -84.436453
# 1      LARCENY-FROM VEHICLE         Downtown   M  33.762549 -84.387874
# 2       LARCENY-NON VEHICLE        Vine City   L  33.755768 -84.416631
# 3       LARCENY-NON VEHICLE       Grant Park   W  33.746503 -84.378535
# 4       LARCENY-NON VEHICLE  Collier Heights   I  33.777383 -84.477433
# ...                     ...              ...  ..        ...        ...
# 17627  LARCENY-FROM VEHICLE  Collier Heights   I  33.786330 -84.492188
# 17628           AGG ASSAULT        Westhaven   I  33.757226 -84.482355
# 17629            AUTO THEFT        Southwest   R  33.692468 -84.490825
# 17630  LARCENY-FROM VEHICLE     East Atlanta   W  33.740555 -84.346336
# 17631  LARCENY-FROM VEHICLE       Grant Park   W  33.728115 -84.364940
#
# [17620 rows x 14 columns]

# %%
cobra_21['rpt_date']= pd.to_datetime(cobra_21['rpt_date'])
cobra_21['occur_date']= pd.to_datetime(cobra_21['occur_date'])
cobra_21['rpt_date'] = cobra_21['rpt_date'].dt.strftime("%m/%d/%Y")
cobra_21['occur_date'] = cobra_21['occur_date'].dt.strftime("%m/%d/%Y")
cobra_21.head()
# Out:
#    offense_id    rpt_date  occur_date occur_year occur_time poss_time  beat  \
# 0    21140096  05/20/2021  05/19/2021       2021      15:20     15:25   103
# 1    21282015  08/06/2021  08/06/2021       2021      22:23     22:24   508
# 2    21791668  06/28/2021  06/27/2021       2021      21:17     20:00   102
# 3   200041082  01/05/2021  01/04/2021       2021      16:00     17:00   605
# 4   202611428  09/18/2021  09/18/2021       2021      18:04     18:15   112
#
#                                             location ibr_code  \
# 0  1720 MARIETTA BLVD NW\r\nATLANTA, GA 30318\r\n...      23F
# 1  300 PEACHTREE ST NE\r\nATLANTA, GA 30308\r\nUN...      23F
# 2  870 MAYSON TURNER RD NW\r\nATLANTA, GA 30314\r...      23H
# 3  275 MEMORIAL DR SE\r\nATLANTA, GEORGIA 30312\r...      23C
# 4  2750 DONALD LEE HOLLOWELL PKWY NW\r\nATLANTA, ...      23C
#
#             UC2_Literal     neighborhood npu        lat       long
# 0  LARCENY-FROM VEHICLE       Hills Park   D  33.801693 -84.436453
# 1  LARCENY-FROM VEHICLE         Downtown   M  33.762549 -84.387874
# 2   LARCENY-NON VEHICLE        Vine City   L  33.755768 -84.416631
# 3   LARCENY-NON VEHICLE       Grant Park   W  33.746503 -84.378535
# 4   LARCENY-NON VEHICLE  Collier Heights   I  33.777383 -84.477433

# %%
concat_list = [cobra_09, cobra_20,cobra_20_Old, cobra_21]  # List of your dataframes
crime_df_complete = pd.concat(concat_list)
crime_df_complete.head()
# Out:
#    offense_id    rpt_date  occur_date occur_year occur_time poss_time   beat  \
# 0    90010930  01/01/2009  01/01/2009       2009       1145    1148.0  411.0
# 1    90011083  01/01/2009  01/01/2009       2009       1330    1330.0  511.0
# 2    90011208  01/01/2009  01/01/2009       2009       1500    1520.0  407.0
# 3    90011218  01/01/2009  01/01/2009       2009       1450    1510.0  210.0
# 4    90011289  01/01/2009  01/01/2009       2009       1600    1700.0  411.0
#
#                       location          UC2_Literal ibr_code neighborhood npu  \
# 0         2841 GREENBRIAR PKWY  LARCENY-NON VEHICLE     2303   Greenbriar   R
# 1               12 BROAD ST SW  LARCENY-NON VEHICLE     2303     Downtown   M
# 2  3500 MARTIN L KING JR DR SW  LARCENY-NON VEHICLE     2303   Adamsville   H
# 3         3393 PEACHTREE RD NE  LARCENY-NON VEHICLE     2303        Lenox   B
# 4      2841 GREENBRIAR PKWY SW  LARCENY-NON VEHICLE     2303   Greenbriar   R
#
#         lat      long
# 0  33.68845 -84.49328
# 1  33.75320 -84.39201
# 2  33.75735 -84.50282
# 3  33.84676 -84.36212
# 4  33.68677 -84.49773

# %%
crime_df_complete.insert(4,'occur_month',crime_df_complete['occur_date'].str[:2])
crime_df_complete.insert(5,'occur_day',crime_df_complete['occur_date'].str[3:5])

# %%
crime_df_complete
# Out:
#        offense_id    rpt_date  occur_date occur_year occur_month occur_day  \
# 0        90010930  01/01/2009  01/01/2009       2009          01        01
# 1        90011083  01/01/2009  01/01/2009       2009          01        01
# 2        90011208  01/01/2009  01/01/2009       2009          01        01
# 3        90011218  01/01/2009  01/01/2009       2009          01        01
# 4        90011289  01/01/2009  01/01/2009       2009          01        01
# ...           ...         ...         ...        ...         ...       ...
# 17627   212940064  10/21/2021  10/21/2021       2021          10        21
# 17628   212940073  10/21/2021  10/21/2021       2021          10        21
# 17629   212940212  10/21/2021  10/21/2021       2021          10        21
# 17630   213000875  08/18/2021  07/10/2021       2021          07        10
# 17631   217421582  10/01/2021  10/01/2021       2021          10        01
#
#       occur_time poss_time   beat  \
# 0           1145    1148.0  411.0
# 1           1330    1330.0  511.0
# 2           1500    1520.0  407.0
# 3           1450    1510.0  210.0
# 4           1600    1700.0  411.0
# ...          ...       ...    ...
# 17627      02:24     02:25    112
# 17628      00:35     00:45    111
# 17629      02:49     03:28    409
# 17630      16:00     12:14    612
# 17631      00:00     20:00    605
#
#                                                 location  \
# 0                                   2841 GREENBRIAR PKWY
# 1                                         12 BROAD ST SW
# 2                            3500 MARTIN L KING JR DR SW
# 3                                   3393 PEACHTREE RD NE
# 4                                2841 GREENBRIAR PKWY SW
# ...                                                  ...
# 17627  3200 DONALD LEE HOLLOWELL PKWY NW\r\nATLANTA, ...
# 17628  71 LINKWOOD RD NW\r\nATL, GA 30311\r\nUNITED S...
# 17629  3113 CAMPBELLTON RD SW\r\nATLANTA, GA 30311\r\...
# 17630  491 FLAT SHOALS AVE SE\r\nATLANTA, GA 30316\r\...
# 17631  655 MEAD ST SE\r\nATLANTA, GA 30312\r\nUNITED ...
#
#                 UC2_Literal ibr_code     neighborhood npu        lat  \
# 0       LARCENY-NON VEHICLE     2303       Greenbriar   R  33.688450
# 1       LARCENY-NON VEHICLE     2303         Downtown   M  33.753200
# 2       LARCENY-NON VEHICLE     2303       Adamsville   H  33.757350
# 3       LARCENY-NON VEHICLE     2303            Lenox   B  33.846760
# 4       LARCENY-NON VEHICLE     2303       Greenbriar   R  33.686770
# ...                     ...      ...              ...  ..        ...
# 17627  LARCENY-FROM VEHICLE      23F  Collier Heights   I  33.786330
# 17628           AGG ASSAULT      13A        Westhaven   I  33.757226
# 17629            AUTO THEFT      240        Southwest   R  33.692468
# 17630  LARCENY-FROM VEHICLE      23F     East Atlanta   W  33.740555
# 17631  LARCENY-FROM VEHICLE      23G       Grant Park   W  33.728115
#
#             long
# 0     -84.493280
# 1     -84.392010
# 2     -84.502820
# 3     -84.362120
# 4     -84.497730
# ...          ...
# 17627 -84.492188
# 17628 -84.482355
# 17629 -84.490825
# 17630 -84.346336
# 17631 -84.364940
#
# [382583 rows x 16 columns]

# %%
county_cases.columns = ['County Name','Cases','County ID','State FIPS Code','County FIPS Code','Population','Hospitalization','Deaths', 'Case Rate', 'Death Rate', '14 Day Case Rate','14 Day Cases','Antigen Cases','Probable Deaths']
county_cases.head()
# Out:
#   County Name  Cases County ID State FIPS Code County FIPS Code  Population  \
# 0     Appling   2761  US-13001              13                1       18561
# 1    Atkinson   1171  US-13003              13                3        8330
# 2       Bacon   1856  US-13005              13                5       11404
# 3       Baker    241  US-13007              13                7        3116
# 4     Baldwin   5232  US-13009              13                9       44428
#
#    Hospitalization  Deaths  Case Rate  Death Rate  14 Day Case Rate  \
# 0              234      94   14875.28      506.44            269.38
# 1              172      29   14057.62      348.14            252.10
# 2              147      47   16274.99      412.14            306.91
# 3               43      13    7734.27      417.20             64.18
# 4              381     162   11776.36      364.63            126.05
#
#    14 Day Cases  Antigen Cases  Probable Deaths
# 0            50            720                9
# 1            21            395                5
# 2            35            646               11
# 3             2            138                1
# 4            56           1399               22

# %%
cobra_20_Old.head()
# Out:
#    offense_id    rpt_date  occur_date occur_year occur_time poss_time   beat  \
# 0   200021209  01/02/2020  01/02/2020       2020      15:21     15:35  511.0
# 1   200061707  01/06/2020  01/06/2020       2020       0:00     18:25  109.0
# 2   200100013  01/10/2020  01/09/2020       2020      23:45      0:00  110.0
# 3   200151818  01/16/2020  01/15/2020       2020      17:15     17:40  401.0
# 4   200180440  01/18/2020  01/18/2020       2020       3:31      3:31  206.0
#
#                  location UC2_Literal       neighborhood npu       lat  \
# 0          12 BROAD ST SW    HOMICIDE           Downtown   M  33.75352
# 1       785 PEYTON AVE NW    HOMICIDE        Center Hill   J  33.77655
# 2       1977 JONES AVE NW    HOMICIDE     West Highlands   G  33.78738
# 3  549 JOSEPH LOWERY BLVD    HOMICIDE           West End   T  33.74001
# 4          28 IRBY AVE NW    HOMICIDE  South Tuxedo Park   B  33.84102
#
#        long
# 0 -84.39189
# 1 -84.46770
# 2 -84.45208
# 3 -84.41782
# 4 -84.38018

# %%
cobra_20_Old= cobra_20_Old.drop(columns=['offense_id','rpt_date','occur_time', 'occur_year','poss_time','beat','location','UC2_Literal','neighborhood','npu','lat','long'])
cobra_20_Old.head()
# Out:
#    occur_date
# 0  01/02/2020
# 1  01/06/2020
# 2  01/09/2020
# 3  01/15/2020
# 4  01/18/2020

# %%
newCrimeData= cobra_20_Old["occur_date"].str.split("/",n=2,expand=True)
newCrimeData.head()
# Out:
#     0   1     2
# 0  01  02  2020
# 1  01  06  2020
# 2  01  09  2020
# 3  01  15  2020
# 4  01  18  2020

# %%
len(newCrimeData)
# Out:
# 14830

# %%
cobra_20_Old["month"]= newCrimeData[0]
cobra_20_Old["day"]= newCrimeData[1]
cobra_20_Old["year"]= newCrimeData[2]
cobra_20_Old.drop(columns=["occur_date"],inplace=True)
cobra_20_Old.head()
# Out:
#   month day  year
# 0    01  02  2020
# 1    01  06  2020
# 2    01  09  2020
# 3    01  15  2020
# 4    01  18  2020

# %%
crimeDataClean = cobra_20_Old[~(cobra_20_Old["month"]> "09")]
crimeDataClean.head()
#crimeDATA2019Clean = crimeDATA2019[~(crimeDATA2019["Occur Date"]< "2019-01-01")]
#crimeDATA2019Clean
# Out:
#   month day  year
# 0    01  02  2020
# 1    01  06  2020
# 2    01  09  2020
# 3    01  15  2020
# 4    01  18  2020

# %%
crimeDATAPlot = cobra_20_Old.groupby(["month"]).count()
crimeDATAPlot = crimeDATAPlot[["day"]]
crimeDATAPlot.rename(columns= {"day": "Counts"}, inplace=True)
crimeDATAPlot

#crimeDATA2020.rename(columns = {"occur_date": "Occur Date"}, inplace=True)
# Out:
#        Counts
# month
# 01       2197
# 02       1777
# 03       1575
# 04       1131
# 05       1340
# 06       1638
# 07       1627
# 08       1806
# 09       1629
# 10          4
# 11          7
# 12         99

# %%
crimeDATAPlot.plot(kind="bar", width = 0.7)
plt.xlabel ("Months")
plt.ylabel ("Counts of Crime Occurences")
plt.title ("Crime vs City Shutdown")
plt.xticks(rotation=0)
plt.show()
